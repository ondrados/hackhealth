# %%
import re
import os
import glob
import pickle
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_pickle("data/train.pkl")

# %%
df.ecg_path.iloc[0]
# Out:
# 'data/kkchb_hosp_csv/356027008.csv'

# %%
sig = pd.read_csv(df.ecg_path.iloc[0])
sig
# Out:
#        I   II   III   aVR   aVL   aVF   V1   V2   V3   V4   V5   V6
# 0    -78   63   141     7  -109   102    4  -39   68  146  107 -122
# 1    -78   63   141     7  -109   102    4  -34   68  146  117 -122
# 2    -68   73   141    -2  -104   107    9  -34   78  151  122 -112
# 3    -68   87   156    -9  -112   122    9  -34   78  156  122 -107
# 4    -53   82   136   -14   -95   109    9  -43   73  156  117 -107
# ...   ..  ...   ...   ...   ...   ...  ...  ...  ...  ...  ...  ... ..
# 4995 -48   53   102    -2   -75    78  156   82   92  -53    9   48
# 4996 -48   82   131   -17   -90   107  156   78   87  -53   14   48
# 4997 -43   97   141   -26   -92   119  156   73   87  -48   19   53
# 4998 -43  102   146   -29   -95   124  161   73   97  -48   19   58
# 4999 -34   78   112   -21   -73    95  165   73  112  -34   29   73
#
# [5000 rows x 13 columns]

# %%
leads = [" V1", " V3", " V6"]
fig, axes = plt.subplots(nrows=3,ncols=1,figsize=(30,15))
for lead in range(len(leads)):
    axes[lead].plot(sig[leads[lead]],label=leads[lead])
    axes[lead].set_xlabel('samples')
    axes[lead].set_title(leads[lead])
plt.show()
